# %% [markdown]
# ## Subplots

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/sampleData2.csv',parse_dates=['Date'],index_col='Date')

# %%
df.head()
# Out:
#                Month  Year  Customer ID  Customer Age       Age Group  \
# Date
# 2013-11-26  November  2013        11019            19     Youth (<25)
# 2015-11-26  November  2015        11019            19     Youth (<25)
# 2014-03-23     March  2014        11039            49  Adults (35-64)
# 2016-03-23     March  2016        11039            49  Adults (35-64)
# 2014-05-15       May  2014        11046            47  Adults (35-64)
#
#            Customer Gender    Country             State Product Category  \
# Date
# 2013-11-26               M     Canada  British Columbia      Accessories
# 2015-11-26               M     Canada  British Columbia      Accessories
# 2014-03-23               M  Australia   New South Wales      Accessories
# 2016-03-23               M  Australia   New South Wales      Accessories
# 2014-05-15               F  Australia   New South Wales      Accessories
#
#            Sub Category              Product  Frame Size  Order Quantity  \
# Date
# ...

# %%
canada = df[df['Country']=='Canada'].Revenue.resample('M').sum()
australia = df[df['Country']=='Australia'].Revenue.resample('M').sum()
usa = df[df['Country']=='United States'].Revenue.resample('M').sum()
germany = df[df['Country']=='Germany'].Revenue.resample('M').sum()
france = df[df['Country']=='France'].Revenue.resample('M').sum()
uk = df[df['Country']=='United Kingdom'].Revenue.resample('M').sum()

# %%
fig,ax = plt.subplots(nrows=2,ncols=3,figsize=(13,8),sharey=True)
ax[0,0].stackplot(canada.index,canada,color='#a83232')
ax[0,1].stackplot(australia.index,australia,color='#1313bd')
ax[0,2].stackplot(usa.index,usa,color='#424bf5')
ax[1,0].stackplot(germany.index,germany,color='#f5ef42')
ax[1,1].stackplot(france.index,france,color='#f56942')
ax[1,2].stackplot(uk.index,uk,color='#f54242')

ax[0,0].set_title('Revenue from Canada')
ax[0,1].set_title('Revenue from Australia')
ax[0,2].set_title('Revenue from United States')
ax[1,0].set_title('Revenue from Germany')
ax[1,1].set_title('Revenue from France')
ax[1,2].set_title('Revenue from United Kingdom')

plt.show()
